# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

mydata = pd.read_csv('dataset.csv')

mydata

# mydata.head(5)

# mydata.tail(5)

# mydata.info()

# mydata.describe()

# mydata.hist(['Total Deaths/Pop'], figsize = (30,40))
# plt.show()

# sns.boxplot(x="Country", y="Total Deaths/Pop", data=mydata)

# pd.crosstab(mydata['Country'],mydata['% Muslim Population'] )

# sns.countplot(x="Country", hue="% Muslim Population", data=mydata)
# Out:
#                             Name   Stars  Forks     Language  \
# 0      freeCodeCamp/freeCodeCamp  224136   8997   JavaScript
# 1                 twbs/bootstrap  105991  48185   JavaScript
# 2                          d3/d3   59462  15847   JavaScript
# 3                 facebook/react   58176  10559   JavaScript
# 4             angular/angular.js   54439  27059   JavaScript
# ..                           ...     ...    ...          ...
# 294             janl/mustache.js   10297   1976   JavaScript
# 295  chriskempson/tomorrow-theme   10280   2317          CSS
# 296                Mantle/Mantle   10276   1429  Objective-C
# 297            loverajoel/jstips   10244    640          CSS
# 298         faif/python-patterns   10229   2460       Python
#
#                                            Description  \
# 0    The https://freeCodeCamp.com open source codeb...
# 1    The most popular HTML, CSS, and JavaScript fra...
# 2    Bring data to life with SVG, Canvas and HTML. ...
# ...
